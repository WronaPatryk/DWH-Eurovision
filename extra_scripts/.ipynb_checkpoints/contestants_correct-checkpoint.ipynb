# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"..\data\old\contestants.csv")

# %%
df.columns
# Out:
# Index(['year', 'to_country_id', 'to_country', 'performer', 'song',
#        'place_contest', 'sf_num', 'running_final', 'running_sf', 'place_final',
#        'points_final', 'place_sf', 'points_sf', 'points_tele_final',
#        'points_jury_final', 'points_tele_sf', 'points_jury_sf', 'composers',
#        'lyricists', 'lyrics', 'youtube_url'],
#       dtype='object')

# %%
df[['composers', 'lyricists', 'youtube_url']]
# Out:
#                    composers            lyricists  \
# 0           Georg Benz Stahl                  NaN
# 1                Cor Lemaire  Annie M. G. Schmidt
# 2     Jacques Say;Jean Miret        Robert Montal
# 3     Walter Andreas Schwarz                  NaN
# 4                André Lodge      Rachèle Thoreau
# ...                      ...                  ...
# 1598                     NaN                  NaN
# 1599                     NaN                  NaN
# 1600                     NaN                  NaN
# 1601                     NaN                  NaN
# 1602                     NaN                  NaN
#
#                                   youtube_url
# 0     https://youtube.com/watch?v=IyqIPvOkiRk
# 1     https://youtube.com/watch?v=u45UQVGRVPA
# 2     https://youtube.com/watch?v=U9O3sqlyra0
# 3     https://youtube.com/watch?v=BDNARIDnmTc
# 4     https://youtube.com/watch?v=dm1L0XyikKI
# ...                                       ...
# 1598  https://youtube.com/watch?v=EgONBKFQpxE
# 1599  https://youtube.com/watch?v=LjNK4Xywjc4
# 1600  https://youtube.com/watch?v=ELr6U2fOrnE
# 1601  https://youtube.com/watch?v=eIZ48w4epng
# 1602  https://youtube.com/watch?v=O9GAfFHZE-E
#
# [1603 rows x 3 columns]

# %%
df.sample(5)
# Out:
#       year to_country_id  to_country          performer          song  \
# 366   1979            de     Germany    Dschinghis Khan           NaN
# 1087  2008            fr      France  Sébastien Tellier        Divine
# 1136  2009            fi     Finland     Waldo's People  Lose Control
# 131   1965            yu  Yugoslavia         Vice Vukov        Ceznja
# 1209  2011            ro     Romania           Hotel FM        Change
#
#       place_contest  sf_num  running_final  running_sf  place_final  ...  \
# 366             4.0     NaN            9.0         NaN          4.0  ...
# 1087           19.0     NaN           19.0         NaN         19.0  ...
# 1136           25.0     1.0           24.0        15.0         25.0  ...
# 131            12.0     NaN           17.0         NaN         12.0  ...
# 1209           17.0     2.0           17.0        14.0         17.0  ...
#
#       place_sf  points_sf  points_tele_final  points_jury_final  \
# 366        NaN        NaN                NaN                NaN
# 1087       NaN        NaN                NaN                NaN
# 1136      12.0       42.0                NaN                NaN
# 131        NaN        NaN                NaN                NaN
# 1209       4.0      111.0                NaN                NaN
#
#       points_tele_sf  points_jury_sf                        composers  \
# 366              NaN             NaN                     Ralph Siegel
# 1087             NaN             NaN                Sébastien Tellier
# 1136             NaN             NaN  Ari Erik Veikko Lehtonen;Karima
# 131              NaN             NaN                      Julio Marić
# 1209             NaN             NaN                   Gabriel Băruţă
#
#                                               lyricists  \
# 366                                     Gunter Johansen
# 1087       Amandine de La Richardière;Sébastien Tellier
# 1136  Annie Kratz-Gutå;Ari Erik Veikko Lehtonen;Kari...
# 131                                          Žarko Roje
# 1209                      Alexandra Ivan;Gabriel Băruţă
#
#                                                  lyrics  \
# 366   Hu, ha, hu, ha... hu, ha, hu, ha...\nHu, ha, h...
# 1087  No no no no no no no\nI'm looking for a band t...
# 1136  I don't wanna lose control, but I'm falling, f...
# 131   Šumi, šumi more pjenom bijelom dok nemirni val...
# 1209  You think you've got the time to figure it out...
#
#                                   youtube_url
# 366   https://youtube.com/watch?v=eAEUrp2V4ss
# 1087  https://youtube.com/watch?v=CZQjBCvFd9E
# 1136  https://youtube.com/watch?v=D-Wr0z1_quw
# 131   https://youtube.com/watch?v=iXJxDa05ywE
# 1209  https://youtube.com/watch?v=2a1Q_hpGLbs
#
# [5 rows x 21 columns]

# %%
df = df.drop(['composers', 'lyricists', 'youtube_url'], axis=1)

# %%
df['to_country'] = df['to_country'].replace(['Serbia & Montenegro'],'Serbia and Montenegro')
df['to_country'] = df['to_country'].replace(['North Macedonia'],'Macedonia')
df['to_country'] = df['to_country'].replace(['Bosnia & Herzegovina'],'Bosnia and Herzegovina')

# %%
df.columns = ['Year', 'Country id', 'Country', 'Artist', 'Song', 'Overall place', 'Which semifinal', 'Final running order', 'Semifinal running order', 'Final place', 'Final points', 'Semifinal place', 'Semifinal points', 'Final televoting points', 'Final jury points', 'Semifinal televoting points', 'Semifinal jury points', 'Lyrics length']

# %%
df.sample(10)
# Out:
#       Year  Country id     Country                              Artist  \
# 1036  2007          md     Moldova                       Natalia Barbu
# 912   2003          lv      Latvia                              F.L.Y.
# 955   2005          lv      Latvia                      Walter & Kazha
# 1563  2020          de     Germany                           Ben Dolic
# 1319  2014          se      Sweden                       Sanna Nielsen
# 1594  2020          al     Albania                         Arilena Ara
# 415   1981          yu  Yugoslavia                    Seid-Memic Vajta
# 1392  2015  San Marino  San Marino  Michele Perniola & Anita Simoncini
# 1206  2011          rs      Serbia                                Nina
# 573   1989          de     Germany                      Nino de Angelo
#
#                      Song  Overall place  Which semifinal  \
# 1036                Fight           10.0              0.0
# 912       Hello From Mars           24.0              NaN
# 955   The War Is Not Over            5.0              0.0
# 1563        Violent Thing            NaN              NaN
# 1319                 Undo            3.0              1.0
# 1594    Fall From The Sky            NaN              2.0
# 415                 Leila           15.0              NaN
# 1392      Chain Of Lights           39.0              2.0
# 1206              Čaroban           14.0              1.0
# 573               Flieger           14.0              NaN
#
#       Final running order  Semifinal running order  Final place  Final points  \
# 1036                 24.0                      9.0         10.0         109.0
# 912                  21.0                      NaN         24.0           5.0
# 955                  23.0                      5.0          5.0         153.0
# 1563                  NaN                      NaN          NaN           NaN
# 1319                 13.0                      4.0          3.0         218.0
# 1594                  NaN                      NaN          NaN           NaN
# 415                   7.0                      NaN         15.0          35.0
# 1392                  NaN                      3.0          NaN           NaN
# 1206                 24.0                      6.0         14.0          85.0
# 573                  21.0                      NaN         14.0          46.0
#
#       Semifinal place  Semifinal points  Final televoting points  \
# 1036             10.0              91.0                      NaN
# 912               NaN               NaN                      NaN
# 955              10.0              85.0                      NaN
# 1563              NaN               NaN                      NaN
# 1319              2.0             131.0                      NaN
# 1594              NaN               NaN                      NaN
# 415               NaN               NaN                      NaN
# 1392             16.0              11.0                      NaN
# 1206              8.0              67.0                      NaN
# 573               NaN               NaN                      NaN
#
#       Final jury points  Semifinal televoting points  Semifinal jury points  \
# 1036                NaN                          NaN                    NaN
# 912                 NaN                          NaN                    NaN
# 955                 NaN                          NaN                    NaN
# 1563                NaN                          NaN                    NaN
# 1319                NaN                          NaN                    NaN
# 1594                NaN                          NaN                    NaN
# 415                 NaN                          NaN                    NaN
# 1392                NaN                          NaN                    NaN
# 1206                NaN                          NaN                    NaN
# 573                 NaN                          NaN                    NaN
#
#                                                  Lyrics
# 1036  (Never, never, never, never)\n\nObsession, we ...
# 912   Time would pass me by if I\nHad never asked yo...
# 955   Ta na na na... na na...\nNa na na... na na...\...
# 1563  Got that thing that I can't deny\nKilling me s...
# 1319  Silent I just stood there silent\nWorking up a...
# 1594  Words have cut me to the bone\nAnd my heart is...
# 415   Nikad te niko neće voljet' k'o ja, nikada\nNik...
# 1392  No\n\nI don't wanna dream forever\nOf a time w...
# 1206  Ciča zima i svud je prokleti led\nBaš sam imal...
# 573   Du und ich, wir sind so hoch geflogen\nVor gar...

# %%
df['Lyrics length'] = df.apply(lambda row: row['Lyrics length'].encode(), axis=1)

# %%
df.head(20)
# Out:
#     Year Country id         Country                          Artist  \
# 0   1956         ch     Switzerland                       Lys Assia
# 1   1956         nl     Netherlands                     Jetty Paerl
# 2   1956         be         Belgium                     Fud Leclerc
# 3   1956         de         Germany          Walter Andreas Schwarz
# 4   1956         fr          France                    Mathé Altéry
# 5   1956         lu      Luxembourg                  Michèle Arnaud
# 6   1956         it           Italy                 Franca Raimondi
# 7   1956         nl     Netherlands                   Corry Brokken
# 8   1956         be         Belgium                       Mony Marc
# 9   1956         de         Germany                    Freddy Quinn
# 10  1956         fr          France                  Dany Dauberson
# 11  1956         it           Italy                 Tonina Torielli
# 12  1957         nl     Netherlands                   Corry Brokken
# 13  1957         fr          France                Paule Desjardins
# 14  1957         dk         Denmark  Birthe Wilke & Gustav Winckler
# 15  1957         lu      Luxembourg                   Danièle Dupré
# 16  1957         de         Germany                Margot Hielscher
# 17  1957         it           Italy                    Nunzio Gallo
# 18  1957         gb  United Kingdom                 Patricia Bredin
# 19  1957         be         Belgium              Bobbejaan Schoepen
#
#                                Song  Overall place  Which semifinal  \
# 0                           Refrain            2.0              NaN
# 1             De Vogels Van Holland            2.0              NaN
# 2   Messieurs Les Noyés De La Seine            2.0              NaN
# 3     Im Wartesaal Zum Großen Glück            2.0              NaN
# 4                    Le Temps Perdu            2.0              NaN
# 5                      Ne Crois Pas            2.0              NaN
# 6                Aprite Le Finestre            2.0              NaN
# 7                  Voorgoed Voorbij            2.0              NaN
# 8       Le Plus Beau Jour De Ma Vie            2.0              NaN
# 9            So Geht Das Jede Nacht            2.0              NaN
# 10                        Il Est Là            2.0              NaN
# 11                    Amami Se Vuoi            2.0              NaN
# 12                     Net Als Toen            1.0              NaN
# 13                   La Belle Amour            2.0              NaN
# 14          Skibet Skal Sejle I Nat            3.0              NaN
# 15    Amours Mortes (Tant De Peine)            4.0              NaN
# 16                 Telefon, Telefon            4.0              NaN
# 17         Corde Della Mia Chitarra            6.0              NaN
# 18                              All            7.0              NaN
# 19                    Straatdeuntje            8.0              NaN
#
#     Final running order  Semifinal running order  Final place  Final points  \
# 0                   2.0                      NaN          2.0           NaN
# 1                   1.0                      NaN          2.0           NaN
# 2                   3.0                      NaN          2.0           NaN
# 3                   4.0                      NaN          2.0           NaN
# 4                   5.0                      NaN          2.0           NaN
# 5                  13.0                      NaN          2.0           NaN
# 6                   7.0                      NaN          2.0           NaN
# 7                   8.0                      NaN          2.0           NaN
# 8                  10.0                      NaN          2.0           NaN
# 9                  11.0                      NaN          2.0           NaN
# 10                 12.0                      NaN          2.0           NaN
# 11                 14.0                      NaN          2.0           NaN
# 12                  6.0                      NaN          1.0          31.0
# 13                  8.0                      NaN          2.0          17.0
# 14                  9.0                      NaN          3.0          10.0
# 15                  2.0                      NaN          4.0           8.0
# 16                  7.0                      NaN          4.0           8.0
# 17                  4.0                      NaN          6.0           7.0
# 18                  3.0                      NaN          7.0           6.0
# 19                  1.0                      NaN          8.0           5.0
#
#     Semifinal place  Semifinal points  Final televoting points  \
# 0               NaN               NaN                      NaN
# 1               NaN               NaN                      NaN
# 2               NaN               NaN                      NaN
# 3               NaN               NaN                      NaN
# 4               NaN               NaN                      NaN
# 5               NaN               NaN                      NaN
# 6               NaN               NaN                      NaN
# 7               NaN               NaN                      NaN
# 8               NaN               NaN                      NaN
# 9               NaN               NaN                      NaN
# 10              NaN               NaN                      NaN
# 11              NaN               NaN                      NaN
# 12              NaN               NaN                      NaN
# 13              NaN               NaN                      NaN
# 14              NaN               NaN                      NaN
# 15              NaN               NaN                      NaN
# 16              NaN               NaN                      NaN
# 17              NaN               NaN                      NaN
# 18              NaN               NaN                      NaN
# 19              NaN               NaN                      NaN
#
#     Final jury points  Semifinal televoting points  Semifinal jury points  \
# 0                 NaN                          NaN                    NaN
# 1                 NaN                          NaN                    NaN
# 2                 NaN                          NaN                    NaN
# 3                 NaN                          NaN                    NaN
# 4                 NaN                          NaN                    NaN
# 5                 NaN                          NaN                    NaN
# 6                 NaN                          NaN                    NaN
# 7                 NaN                          NaN                    NaN
# 8                 NaN                          NaN                    NaN
# 9                 NaN                          NaN                    NaN
# 10                NaN                          NaN                    NaN
# 11                NaN                          NaN                    NaN
# 12                NaN                          NaN                    NaN
# 13                NaN                          NaN                    NaN
# 14                NaN                          NaN                    NaN
# 15                NaN                          NaN                    NaN
# 16                NaN                          NaN                    NaN
# 17                NaN                          NaN                    NaN
# 18                NaN                          NaN                    NaN
# 19                NaN                          NaN                    NaN
#
#                                                Lyrics
# 0   b"(Refrain d'amour...)\\n\\nRefrain, couleur d...
# 1   b"De vogels van Holland zijn zo muzikaal\\nZe ...
# 2   b"Messieurs les noy\xc3\xa9s de la Seine\\nOuv...
# 3   b'Es gibt einen Hafen, da f\xc3\xa4hrt kaum ei...
# 4   b"Chante, carillon\\nLe chant du temps perdu\\...
# 5   b"Si on te dit qu't'a une belle gueule\\nY a p...
# 6   b"La prima rosa rossa \xc3\xa8 gi\xc3\xa0 sboc...
# 7   b"Voorgoed voorbij\\nNu zijn we nooit meer sam...
# 8   b'Les cloches sonnent\\nTout carillonne\\nLe p...
# 9   b"Am Sonntag mit Jimmy, am Montag mit Jack\\nA...
# 10  b'Je ne peux changer ma vie, il est l\xc3\xa0\...
# 11  b"Mi piace tanto accarezzarti\\nSugli occhi ti...
# 12  b"Zit niet zo suf met die eeuwige krant\\nGaap...
# 13  b"Si vous aimez la nature, les lilas, les p'ti...
# 14  b"Farvel da, min t\xc3\xb8s, og hold dig nu kv...
# 15  b"Toi que j'aime\\nTu m'as fait tant de peine\...
# 16  b"Hallo \xe2\x80\x93 how do you do? \\nHallo \...
# 17  b"\xc3\x88 tornata\\nL'hanno accolta le stesse...
# 18  b"All the golden dreams of yesterday\\nAll the...
# 19  b'Langs de straten danst er een deuntje\\nEn i...

# %%
df['Lyrics length'].apply(len).max()
# Out:
# 3434

# %%
df['Artist'].apply(len).max()
# Out:
# 46

# %%
df['Song'] = df['Song'].astype(str)
df['Song'] = df['Song'].apply(lambda x: x.replace(',', ''))
df['Song'].head(20)
# Out:
# 0                             Refrain
# 1               De Vogels Van Holland
# 2     Messieurs Les Noyés De La Seine
# 3       Im Wartesaal Zum Großen Glück
# 4                      Le Temps Perdu
# 5                        Ne Crois Pas
# 6                  Aprite Le Finestre
# 7                    Voorgoed Voorbij
# 8         Le Plus Beau Jour De Ma Vie
# 9              So Geht Das Jede Nacht
# 10                          Il Est Là
# 11                      Amami Se Vuoi
# 12                       Net Als Toen
# 13                     La Belle Amour
# 14            Skibet Skal Sejle I Nat
# 15      Amours Mortes (Tant De Peine)
# 16                    Telefon Telefon
# 17           Corde Della Mia Chitarra
# 18                                All
# 19                      Straatdeuntje
# Name: Song, dtype: object

# %%
df['Artist'] = df['Artist'].astype(str)
df['Artist'] = df['Artist'].apply(lambda x: x.replace(',', ''))

# %%
df['Lyrics length'] = df['Lyrics length'].astype(str)
df['Lyrics length'] = df['Lyrics length'].apply(len)
df['Lyrics length']
# Out:
# 0       1030
# 1       1369
# 2       1418
# 3       2067
# 4       1185
#         ...
# 1598    1430
# 1599     877
# 1600    1648
# 1601    1102
# 1602     960
# Name: Lyrics, Length: 1603, dtype: int64

# %%
df['Lyrics length'] = df['Lyrics length'].astype(str)
df['Lyrics length'] = df['Lyrics length'].apply(lambda x: x.replace(',', ''))

# %%
df = df[df['Year'] >= 1975]
df = df[df['Year'] <= 2019]

# %%
df.dtypes
# Out:
# Year                             int64
# Country id                      object
# Country                         object
# Artist                          object
# Song                            object
# Overall place                  float64
# Which semifinal                float64
# Final running order            float64
# Semifinal running order        float64
# Final place                    float64
# Final points                   float64
# Semifinal place                float64
# Semifinal points               float64
# Final televoting points        float64
# Final jury points              float64
# Semifinal televoting points    float64
# Semifinal jury points          float64
# Lyrics                          object
# dtype: object

# %%
b = list(df['Year'].unique())
b.sort()
b
# Out:
# [1975,
#  1976,
#  1977,
#  1978,
#  1979,
#  1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019]

# %%
df.to_csv('..\data\contestants.csv', index = False)
