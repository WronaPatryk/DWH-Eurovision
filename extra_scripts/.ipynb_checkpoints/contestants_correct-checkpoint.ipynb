# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"..\data\old\contestants.csv")

# %%
df.columns
# Out:
# Index(['year', 'to_country_id', 'to_country', 'performer', 'song',
#        'place_contest', 'sf_num', 'running_final', 'running_sf', 'place_final',
#        'points_final', 'place_sf', 'points_sf', 'points_tele_final',
#        'points_jury_final', 'points_tele_sf', 'points_jury_sf', 'composers',
#        'lyricists', 'lyrics', 'youtube_url'],
#       dtype='object')

# %%
df[['composers', 'lyricists', 'youtube_url']]
# Out:
#                    composers            lyricists  \
# 0           Georg Benz Stahl                  NaN
# 1                Cor Lemaire  Annie M. G. Schmidt
# 2     Jacques Say;Jean Miret        Robert Montal
# 3     Walter Andreas Schwarz                  NaN
# 4                André Lodge      Rachèle Thoreau
# ...                      ...                  ...
# 1598                     NaN                  NaN
# 1599                     NaN                  NaN
# 1600                     NaN                  NaN
# 1601                     NaN                  NaN
# 1602                     NaN                  NaN
#
#                                   youtube_url
# 0     https://youtube.com/watch?v=IyqIPvOkiRk
# 1     https://youtube.com/watch?v=u45UQVGRVPA
# 2     https://youtube.com/watch?v=U9O3sqlyra0
# 3     https://youtube.com/watch?v=BDNARIDnmTc
# 4     https://youtube.com/watch?v=dm1L0XyikKI
# ...                                       ...
# 1598  https://youtube.com/watch?v=EgONBKFQpxE
# 1599  https://youtube.com/watch?v=LjNK4Xywjc4
# 1600  https://youtube.com/watch?v=ELr6U2fOrnE
# 1601  https://youtube.com/watch?v=eIZ48w4epng
# 1602  https://youtube.com/watch?v=O9GAfFHZE-E
#
# [1603 rows x 3 columns]

# %%
df.sample(5)
# Out:
#       year to_country_id   to_country                       performer  \
# 594   1990            lu   Luxembourg                    Céline Carzo
# 1569  2020       Belarus      Belarus                             VAL
# 319   1976            gr       Greece                     Mariza Koch
# 14    1957            dk      Denmark  Birthe Wilke & Gustav Winckler
# 886   2002            ch  Switzerland                  Francine Jordi
#
#                             song  place_contest  sf_num  running_final  \
# 594             Quand Je Te Rêve           13.0     NaN            6.0
# 1569                    Da vidna            NaN     1.0            NaN
# 319   Panaghia Mou, Panaghia Mou           13.0     NaN           10.0
# 14       Skibet Skal Sejle I Nat            3.0     NaN            9.0
# 886    Dans Le Jardin De Mon Âme           22.0     NaN           11.0
#
#       running_sf  place_final  ...  place_sf  points_sf  points_tele_final  \
# 594          NaN         13.0  ...       NaN        NaN                NaN
# 1569         NaN          NaN  ...       NaN        NaN                NaN
# 319          NaN         13.0  ...       NaN        NaN                NaN
# 14           NaN          3.0  ...       NaN        NaN                NaN
# 886          NaN         22.0  ...       NaN        NaN                NaN
#
#       points_jury_final  points_tele_sf  points_jury_sf            composers  \
# 594                 NaN             NaN             NaN  Jean-Charles France
# 1569                NaN             NaN             NaN                  NaN
# 319                 NaN             NaN             NaN          Mariza Koch
# 14                  NaN             NaN             NaN           Erik Fiehn
# 886                 NaN             NaN             NaN       Francine Jordi
#
#              lyricists                                             lyrics  \
# 594   Thierry Delianis  Je te vois tout en haut des tours\nDans les bu...
# 1569               NaN  Zaplyatala vosyenʹ yasnu kosami dy rasplyala\n...
# 319   Michael Fotiades  Kabos gematos portokalia, oi-oi mana m'\nPu pe...
# 14       Poul Sørensen  Farvel da, min tøs, og hold dig nu kvik\nJeg t...
# 886                NaN  Je rêve d'une tonnelle\nQui n'appartient qu'à ...
#
#                                   youtube_url
# 594   https://youtube.com/watch?v=U19ABsr7Ruw
# 1569  https://youtube.com/watch?v=F0wfxz5zq04
# 319   https://youtube.com/watch?v=hC8jZeXVC9Q
# 14    https://youtube.com/watch?v=vX3WRMF5TuY
# 886   https://youtube.com/watch?v=EZEEvq1i7PA
#
# [5 rows x 21 columns]

# %%
df = df.drop(['composers', 'lyricists', 'youtube_url'], axis=1)

# %%
df['to_country'] = df['to_country'].replace(['Serbia & Montenegro'],'Serbia and Montenegro')
df['to_country'] = df['to_country'].replace(['North Macedonia'],'Macedonia')
df['to_country'] = df['to_country'].replace(['Bosnia & Herzegovina'],'Bosnia and Herzegovina')

# %%
df.columns = ['Year', 'Country id', 'Country', 'Artist', 'Song', 'Overall place', 'Which semifinal', 'Final running order', 'Semifinal running order', 'Final place', 'Final points', 'Semifinal place', 'Semifinal points', 'Final televoting points', 'Final jury points', 'Semifinal televoting points', 'Semifinal jury points', 'Lyrics']

# %%
df.sample(10)
# Out:
#       Year Country id     Country                            Artist  \
# 1557  2019    Armenia     Armenia                             Srbuk
# 1568  2020  Australia   Australia                         Montaigne
# 193   1969         fr      France                     Frida Boccara
# 1306  2013   Bulgaria    Bulgaria  Elitsa Todorova, Stoyan Yankulov
# 1579  2020     Cyprus      Cyprus                    Sandro Nicolas
# 1502  2018         fi     Finland                       Saara Aalto
# 560   1989         yu  Yugoslavia                              Riva
# 1490  2018         fr      France                   Madame Monsieur
# 1496  2018         rs      Serbia            Sanja Ilić & Balkanika
# 1362  2015         il      Israel                       Nadav Guedj
#
#                     Song  Overall place  Which semifinal  Final running order  \
# 1557         Walking Out           37.0              2.0                  NaN
# 1568      Don't Break Me            NaN              1.0                  NaN
# 193   Un Jour, Un Enfant            1.0              NaN                 14.0
# 1306      Samo Shampioni           29.0              2.0                  NaN
# 1579             Running            NaN              1.0                  NaN
# 1502            Monsters           25.0              1.0                 17.0
# 560              Rock Me            1.0              NaN                 22.0
# 1490               Mercy           13.0              NaN                 13.0
# 1496           Nova Deca           19.0              2.0                 10.0
# 1362          Golden Boy            9.0              2.0                  3.0
#
#       Semifinal running order  Final place  Final points  Semifinal place  \
# 1557                      1.0          NaN           NaN             16.0
# 1568                      NaN          NaN           NaN              NaN
# 193                       NaN          1.0          18.0              NaN
# 1306                      7.0          NaN           NaN             12.0
# 1579                      NaN          NaN           NaN              NaN
# 1502                     15.0         25.0          46.0             10.0
# 560                       NaN          1.0         137.0              NaN
# 1490                      NaN         13.0         173.0              NaN
# 1496                      3.0         19.0         113.0              9.0
# 1362                      9.0          9.0          97.0              3.0
#
#       Semifinal points  Final televoting points  Final jury points  \
# 1557              49.0                      NaN                NaN
# 1568               NaN                      NaN                NaN
# 193                NaN                      NaN                NaN
# 1306              45.0                      NaN                NaN
# 1579               NaN                      NaN                NaN
# 1502             108.0                     23.0               23.0
# 560                NaN                      NaN                NaN
# 1490               NaN                     59.0              114.0
# 1496             117.0                     75.0               38.0
# 1362             151.0                      NaN                NaN
#
#       Semifinal televoting points  Semifinal jury points  \
# 1557                         23.0                   26.0
# 1568                          NaN                    NaN
# 193                           NaN                    NaN
# 1306                          NaN                    NaN
# 1579                          NaN                    NaN
# 1502                         73.0                   35.0
# 560                           NaN                    NaN
# 1490                          NaN                    NaN
# 1496                         72.0                   45.0
# 1362                          NaN                    NaN
#
#                                                  Lyrics
# 1557  Who are you?\nWhat you really do?\nWhen you ha...
# 1568  I don't feel the same buzz\nWhen your name com...
# 193   Un jour se lèvera sur trois branches de lilas\...
# 1306  Samo shampioni, samo shampioni\n\nPrelitat vis...
# 1579  I don't feel like talking, let me sit here alo...
# 1502  Closed my eyes\nSo I couldn't see it\nFelt so ...
# 560   Oh... whoa oh oh oh...\n\nOn cijele dane svir'...
# 1490  Je suis née ce matin\nJe m'appelle Mercy\nAu m...
# 1496  Aj, da ja danem\nI da zaštu sum te mila\nA što...
# 1362  Mama, someone broke my heart again\nTell her I...

# %%
df['Lyrics'] = df.apply(lambda row: row['Lyrics'].encode(), axis=1)

# %%
df.head(20)
# Out:
#     Year Country id         Country                          Artist  \
# 0   1956         ch     Switzerland                       Lys Assia
# 1   1956         nl     Netherlands                     Jetty Paerl
# 2   1956         be         Belgium                     Fud Leclerc
# 3   1956         de         Germany          Walter Andreas Schwarz
# 4   1956         fr          France                    Mathé Altéry
# 5   1956         lu      Luxembourg                  Michèle Arnaud
# 6   1956         it           Italy                 Franca Raimondi
# 7   1956         nl     Netherlands                   Corry Brokken
# 8   1956         be         Belgium                       Mony Marc
# 9   1956         de         Germany                    Freddy Quinn
# 10  1956         fr          France                  Dany Dauberson
# 11  1956         it           Italy                 Tonina Torielli
# 12  1957         nl     Netherlands                   Corry Brokken
# 13  1957         fr          France                Paule Desjardins
# 14  1957         dk         Denmark  Birthe Wilke & Gustav Winckler
# 15  1957         lu      Luxembourg                   Danièle Dupré
# 16  1957         de         Germany                Margot Hielscher
# 17  1957         it           Italy                    Nunzio Gallo
# 18  1957         gb  United Kingdom                 Patricia Bredin
# 19  1957         be         Belgium              Bobbejaan Schoepen
#
#                                Song  Overall place  Which semifinal  \
# 0                           Refrain            2.0              NaN
# 1             De Vogels Van Holland            2.0              NaN
# 2   Messieurs Les Noyés De La Seine            2.0              NaN
# 3     Im Wartesaal Zum Großen Glück            2.0              NaN
# 4                    Le Temps Perdu            2.0              NaN
# 5                      Ne Crois Pas            2.0              NaN
# 6                Aprite Le Finestre            2.0              NaN
# 7                  Voorgoed Voorbij            2.0              NaN
# 8       Le Plus Beau Jour De Ma Vie            2.0              NaN
# 9            So Geht Das Jede Nacht            2.0              NaN
# 10                        Il Est Là            2.0              NaN
# 11                    Amami Se Vuoi            2.0              NaN
# 12                     Net Als Toen            1.0              NaN
# 13                   La Belle Amour            2.0              NaN
# 14          Skibet Skal Sejle I Nat            3.0              NaN
# 15    Amours Mortes (Tant De Peine)            4.0              NaN
# 16                 Telefon, Telefon            4.0              NaN
# 17         Corde Della Mia Chitarra            6.0              NaN
# 18                              All            7.0              NaN
# 19                    Straatdeuntje            8.0              NaN
#
#     Final running order  Semifinal running order  Final place  Final points  \
# 0                   2.0                      NaN          2.0           NaN
# 1                   1.0                      NaN          2.0           NaN
# 2                   3.0                      NaN          2.0           NaN
# 3                   4.0                      NaN          2.0           NaN
# 4                   5.0                      NaN          2.0           NaN
# 5                  13.0                      NaN          2.0           NaN
# 6                   7.0                      NaN          2.0           NaN
# 7                   8.0                      NaN          2.0           NaN
# 8                  10.0                      NaN          2.0           NaN
# 9                  11.0                      NaN          2.0           NaN
# 10                 12.0                      NaN          2.0           NaN
# 11                 14.0                      NaN          2.0           NaN
# 12                  6.0                      NaN          1.0          31.0
# 13                  8.0                      NaN          2.0          17.0
# 14                  9.0                      NaN          3.0          10.0
# 15                  2.0                      NaN          4.0           8.0
# 16                  7.0                      NaN          4.0           8.0
# 17                  4.0                      NaN          6.0           7.0
# 18                  3.0                      NaN          7.0           6.0
# 19                  1.0                      NaN          8.0           5.0
#
#     Semifinal place  Semifinal points  Final televoting points  \
# 0               NaN               NaN                      NaN
# 1               NaN               NaN                      NaN
# 2               NaN               NaN                      NaN
# 3               NaN               NaN                      NaN
# 4               NaN               NaN                      NaN
# 5               NaN               NaN                      NaN
# 6               NaN               NaN                      NaN
# 7               NaN               NaN                      NaN
# 8               NaN               NaN                      NaN
# 9               NaN               NaN                      NaN
# 10              NaN               NaN                      NaN
# 11              NaN               NaN                      NaN
# 12              NaN               NaN                      NaN
# 13              NaN               NaN                      NaN
# 14              NaN               NaN                      NaN
# 15              NaN               NaN                      NaN
# 16              NaN               NaN                      NaN
# 17              NaN               NaN                      NaN
# 18              NaN               NaN                      NaN
# 19              NaN               NaN                      NaN
#
#     Final jury points  Semifinal televoting points  Semifinal jury points  \
# 0                 NaN                          NaN                    NaN
# 1                 NaN                          NaN                    NaN
# 2                 NaN                          NaN                    NaN
# 3                 NaN                          NaN                    NaN
# 4                 NaN                          NaN                    NaN
# 5                 NaN                          NaN                    NaN
# 6                 NaN                          NaN                    NaN
# 7                 NaN                          NaN                    NaN
# 8                 NaN                          NaN                    NaN
# 9                 NaN                          NaN                    NaN
# 10                NaN                          NaN                    NaN
# 11                NaN                          NaN                    NaN
# 12                NaN                          NaN                    NaN
# 13                NaN                          NaN                    NaN
# 14                NaN                          NaN                    NaN
# 15                NaN                          NaN                    NaN
# 16                NaN                          NaN                    NaN
# 17                NaN                          NaN                    NaN
# 18                NaN                          NaN                    NaN
# 19                NaN                          NaN                    NaN
#
#                                                Lyrics
# 0   b"(Refrain d'amour...)\\n\\nRefrain, couleur d...
# 1   b"De vogels van Holland zijn zo muzikaal\\nZe ...
# 2   b"Messieurs les noy\xc3\xa9s de la Seine\\nOuv...
# 3   b'Es gibt einen Hafen, da f\xc3\xa4hrt kaum ei...
# 4   b"Chante, carillon\\nLe chant du temps perdu\\...
# 5   b"Si on te dit qu't'a une belle gueule\\nY a p...
# 6   b"La prima rosa rossa \xc3\xa8 gi\xc3\xa0 sboc...
# 7   b"Voorgoed voorbij\\nNu zijn we nooit meer sam...
# 8   b'Les cloches sonnent\\nTout carillonne\\nLe p...
# 9   b"Am Sonntag mit Jimmy, am Montag mit Jack\\nA...
# 10  b'Je ne peux changer ma vie, il est l\xc3\xa0\...
# 11  b"Mi piace tanto accarezzarti\\nSugli occhi ti...
# 12  b"Zit niet zo suf met die eeuwige krant\\nGaap...
# 13  b"Si vous aimez la nature, les lilas, les p'ti...
# 14  b"Farvel da, min t\xc3\xb8s, og hold dig nu kv...
# 15  b"Toi que j'aime\\nTu m'as fait tant de peine\...
# 16  b"Hallo \xe2\x80\x93 how do you do? \\nHallo \...
# 17  b"\xc3\x88 tornata\\nL'hanno accolta le stesse...
# 18  b"All the golden dreams of yesterday\\nAll the...
# 19  b'Langs de straten danst er een deuntje\\nEn i...

# %%
df['Lyrics'].apply(len).max()
# Out:
# 3434

# %%
df['Artist'].apply(len).max()
# Out:
# 46

# %%
df['Song'] = df['Song'].astype(str)
df['Song'] = df['Song'].apply(lambda x: x.replace(',', ''))
df['Song'].head(20)
# Out:
# 0                             Refrain
# 1               De Vogels Van Holland
# 2     Messieurs Les Noyés De La Seine
# 3       Im Wartesaal Zum Großen Glück
# 4                      Le Temps Perdu
# 5                        Ne Crois Pas
# 6                  Aprite Le Finestre
# 7                    Voorgoed Voorbij
# 8         Le Plus Beau Jour De Ma Vie
# 9              So Geht Das Jede Nacht
# 10                          Il Est Là
# 11                      Amami Se Vuoi
# 12                       Net Als Toen
# 13                     La Belle Amour
# 14            Skibet Skal Sejle I Nat
# 15      Amours Mortes (Tant De Peine)
# 16                    Telefon Telefon
# 17           Corde Della Mia Chitarra
# 18                                All
# 19                      Straatdeuntje
# Name: Song, dtype: object

# %%
df['Artist'] = df['Artist'].astype(str)
df['Artist'] = df['Artist'].apply(lambda x: x.replace(',', ''))

# %%
df['Lyrics'] = df['Lyrics'].astype(str)
df['Lyrics'] = df['Lyrics'].apply(len)
df['Lyrics']
# Out:
# 0       1030
# 1       1369
# 2       1418
# 3       2067
# 4       1185
#         ...
# 1598    1430
# 1599     877
# 1600    1648
# 1601    1102
# 1602     960
# Name: Lyrics, Length: 1603, dtype: int64

# %%
df['Lyrics'] = df['Lyrics'].astype(str)
df['Lyrics'] = df['Lyrics'].apply(lambda x: x.replace(',', ''))

# %%
df = df[df['Year'] >= 1975]

# %%
df.dtypes
# Out:
# Year                             int64
# Country id                      object
# Country                         object
# Artist                          object
# Song                            object
# Overall place                  float64
# Which semifinal                float64
# Final running order            float64
# Semifinal running order        float64
# Final place                    float64
# Final points                   float64
# Semifinal place                float64
# Semifinal points               float64
# Final televoting points        float64
# Final jury points              float64
# Semifinal televoting points    float64
# Semifinal jury points          float64
# Lyrics                          object
# dtype: object

# %%
df.to_csv('..\data\contestants.csv', index = False)
